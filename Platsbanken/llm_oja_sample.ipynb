# %% [markdown]
# # Sample of OJA (without ID) to test LLM on

# %%
import pandas as pd

# Läs in filen
df = pd.read_csv('sample_utan_id.csv')

df = df[["sample_index", "description.text", "description.text_formatted"]]

# Visa de första raderna
print(df.head())
# Out:
#    sample_index                                   description.text  \
# 0          8287  Restaurang Pizza Mix \r\n\r\nPizza Mix Restaur...
# 1         12577  Vill du ha en central roll i ett företag som g...
# 2         39718  Jobbify är en jobbplattform för erfarna kandid...
# 3         37914  Vem är du:\r\n\r\nVi ser gärna att du som söke...
# 4          3574  This is us \r\nQinshift and Avenga merge toget...
#
#                           description.text_formatted
# 0  Restaurang Pizza Mix <br><br>Pizza Mix Restaur...
# 1  Vill du ha en central roll i ett företag som g...
# 2  <strong>Jobbify är en jobbplattform för erfarn...
# 3  Vem är du:\r\n\r\nVi ser gärna att du som söke...
# 4  <p><strong>This is us </strong></p><p>Qinshift...

# %%
import openai
client = openai.OpenAI(
    api_key = "sk-e9569ae26670446d907b3468898172b3",    # Den här koden behöver genereras och ändras för varje användare
    base_url = "https://llm.lab.sspcloud.fr/api"
)

response = client.chat.completions.create(
    model = "devstral:latest",
    messages = [
        {"role":"system","content":"Du är en expert som ger en kort sammanfattar vad företag har för verksamhet utifårn texter jag ger dig."},
        {"role":"user", "content":f"Sammanfatta kort vad företagets huvusakliga verksamhet är enligt texten: {df["description.text"][1]}"}
    ],
    temperature = 0.9
)

print(response.choices[0].message.content)
# Out:
# Företaget är ett konsultföretag som specialiserar sig på kompetensbaserad och fördomsfri rekrytering, bemanning och interim. De erbjuder en tidsbegränsad deltidsroll (50 %) med administrativa uppgifter för en kund som arbetar med klimatfrågor. Uppdraget är på 12–18 månader och kräver minst fem års erfarenhet inom en liknande administrativ roll samt en kandidatexamen i företagsekonomi eller liknande.
