# %% [markdown]
# # Sample of OJA (without ID) to test LLM on

# %%
import pandas as pd

# Ange sökvägen till din CSV-fil
filnamn = 'sample_utan_id.csv'

# Läs in filen
df = pd.read_csv(filnamn)

# Visa de första raderna
print(df.head())
# Out:
#                          external_id  original_id label  \
# 0                                NaN          NaN    []
# 1  46-556648-2781-00000148785b8a7533          NaN    []
# 2             46-559522-3099-59253-2          NaN    []
# 3     46-556622-8846-3512709-6244-se          NaN    []
# 4           46-556588-5935-5788192-1          NaN    []
#
#                                          webpage_url  \
# 0  https://arbetsformedlingen.se/platsbanken/anno...
# 1  https://arbetsformedlingen.se/platsbanken/anno...
# 2  https://arbetsformedlingen.se/platsbanken/anno...
# 3  https://arbetsformedlingen.se/platsbanken/anno...
# 4  https://arbetsformedlingen.se/platsbanken/anno...
#
#                                             logo_url  \
# 0                                                NaN
# 1  https://arbetsformedlingen.se/rest/agas/api/v1...
# 2                                                NaN
# 3  https://arbetsformedlingen.se/rest/agas/api/v1...
# ...
