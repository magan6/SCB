# %%
import requests
import json

"""
Install python packages:
pip install -r requirements.txt

"""

url = 'https://jobsearch.api.jobtechdev.se'
url_for_search = f"{url}/search"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nNumber of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        print(f"{hit['headline']}, {hit['employer']['name']}")


if __name__ == '__main__':
    query = 'lärare uppsala'
    example_search_loop_through_hits(query)
    example_search_return_number_of_hits(query)
# Out:
# Lärare matematik vid Folkuniversitetets gymnasieskolor i Uppsala, Folkuniversitetet Stift Kurs- Verksamheten
# Movant AB i Uppsala söker lärare inom VVS, Movant AB
# JENSEN gymnasium Uppsala söker lärare i matematik och idrott, Jensen Education AB
# Lärare i hem- och konsumentkunskap på SiS, Statens Institutionsstyrelse
# Matematiklärare på Introduktionsprogrammet, Uppsala kommun
# Är du vår nya lärare för åk F-3?, Gluntens Montessoriskola AB
# Är du vår nya lärare för åk 7-9?, Gluntens Montessoriskola AB
# Lärare i Svenska, STEAM Education holding AB
# Gymnasielärare i ekonomiämnen, Uppsala kommun
# Yrkesgymnasiet söker gymnasielärare till Vård och omsorgsprogrammet, Edukatus Alliance AB
# ProCivitas Uppsala söker gymnasielärare i spanska 40%, Procivitas Privata Gymnasium AB
# Lärare i NO och teknik 6-9 till Björkvallsskolan, Uppsala kommun
# Yrkeslärare till Fordonsprogrammet, Personbilsmekaniker , Bergstrands Gymnasium AB
# Förskollärare och lärare till olika skolformer, Clockwork Bemanning & Rekrytering AB
# Lärare i franska, Amerikanska Gymnasiet i Sverige AB
# Lärare i teknik och annat ämne till Ärentunaskolan, Uppsala kommun
# JENSEN grundskola Kåbo F-3 söker lärare i fritidshem på 75 %, Jensen Education AB
# Musiklärare i årskurs 4-9, Kunskapsskolan i Sverige AB
# Gymnasielärare i Försäljning och service, Edukatus Alliance AB
# JENSEN grundskola Kåbo 4-9 söker lärare i musik kombinerat med annat ämne, Jensen Education AB
# Assisterande lärare/Barnskötare sökes till Liten Lärs 1-årsgrupp, Stift Liten Lär
# Lärare i Kemi, Amerikanska Gymnasiet i Sverige AB
# Lärare i spanska och/eller italienska, Amerikanska Gymnasiet i Sverige AB
# Jobba som lärare på Sveriges bästa och mest personliga bemanningsföretag!, PersonalExpressen AB
# Lärare inom flygbassystemet SO 7/6, Försvarsmakten
# Lärare inom flygbassystemet SO 6/7, Försvarsmakten
#
# Number of hits = 26

# %%
import requests
import json

"""
Install python packages:
pip install -r requirements.txt
"""

url = 'https://links.api.jobtechdev.se'
url_for_search = f"{url}/joblinks"


def _get_ads(params):
    headers = {'accept': 'application/json'}
    response = requests.get(url_for_search, headers=headers, params=params)
    response.raise_for_status()  # check for http errors
    return json.loads(response.content.decode('utf8'))


def _print_ad(ad):
    print(f"{ad['headline']}, {ad['employer']['name']}")
    source_links = [item['label'] for item in ad['source_links']]
    print(source_links)
    print(ad['brief'])  # 'brief' is a shortened description from the original ad
    print()


def example_search_return_number_of_hits(query):
    # limit: 0 means no ads, just a value of how many ads were found.
    search_params = {'q': query, 'limit': 0}
    json_response = _get_ads(search_params)
    number_of_hits = json_response['total']['value']
    print(f"\nTotal number of hits = {number_of_hits}")


def example_search_loop_through_hits(query):
    # limit = 100 is the max number of hits that can be returned.
    # If there are more (which you find with ['total']['value'] in the json response)
    # you have to use offset and multiple requests to get all ads.
    search_params = {'q': query, 'limit': 100}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        _print_ad(hit)
    print('---------------------------\n')


def example_filter_source(query):
    """
    This example excludes all hits that comes from Arbetsförmedlingen and only show results from other sources
    the field 'source_links' in the ad is a list of the source(s) where the original ad was found
    """
    exclude = 'arbetsformedlingen.se'
    limit = 100
    search_params = {'q': query, 'limit': limit, 'exclude_source': exclude}
    json_response = _get_ads(search_params)
    hits = json_response['hits']
    for hit in hits:
        _print_ad(hit)
    number_of_hits = json_response['total']['value']
    print(f"Number of hits, excluding {exclude} = {number_of_hits}")


if __name__ == '__main__':
    query = 'lärare'
    example_search_loop_through_hits(query)
    example_filter_source(query)
    example_search_return_number_of_hits(query)
# Out:
# Kock, asiatisk kock, Vu, Thi Thuy
# ['arbetsformedlingen.se']
# Vi söker erfaren asiatisk kock Vi söker nu en erfaren och engagerad kock med specialisering inom asiatisk matlagning, gärna vietnamesisk, till vår restaurang. Kvalifikationer: Erfarenhet av asiatisk matlagning är ett krav – gärna asiatisk kök.
#
# Kock, Östersunds kommun
# ['arbetsformedlingen.se']
# Ditt nya jobbVi söker dig som vill vara med och bidra till ett gott liv och ett bättre Östersund genom att erbjuda bästa möjliga måltider för våra gäster. Måltidsservice är en sektor inom Östersunds kommun, Teknisk förvaltning.
#
# Kock, Järfälla kommun
# ['arbetsformedlingen.se']
# På Utbildningsförvaltningen i Järfälla kommun arbetar omkring 3 100 medarbetare i någon av våra 39 förskolor, 22 skolor, gymnasium, vuxenutbildning och central förvaltning. Vår verksamhet präglas av våra ledord: professionalitet, kollegialitet och utvecklingskraft.
#
# Kock, Järfälla kommun, Kvarnskolan
# ['offentligajobb.se']
# Om arbetsplatsenPå Utbildningsförvaltningen i Järfälla kommun arbetar omkring 3 100 medarbetare i någon av våra 39 förskolor, 22 skolor, gymnasium, vuxenutbildning och central förvaltning. Vår verksamhet präglas av våra ledord: professionalitet, kollegialitet och utvecklingskraft.
#
# Kock, Hotel Dalecarlia AB
# ['arbetsformedlingen.se']
# Dalecarlia  Hotel & SPA i vackra Tällberg i Dalarna söker erfaren kock som vill vara med och jobba i ett team som sätter matlagning och gästen i fokus. Du har stor passion för ditt yrke och är kreativ.
#
# Kock, verde Dipp AB
# ['arbetsformedlingen.se']
# Restaurang The Elephant Redbergsvägen 9 i Göteborg är en Indisk restaurang som skall servera  Indisk mat båda tandoori och curry rätter, nu behöver vi en kock som kan förbereda och laga Indisk mat ,som kan ta emot och förvara varorna. Öppen för allaVi fokuserar på din kompetens, inte dina övriga förutsättningar.
#
# Kock , Malthuset Restaurang AB
# ['arbetsformedlingen.se']
# A la Carte Kock Sökes till Restaurang Bryggeriet i Göteborg!Plats: Avenyn 3, GöteborgKök: Svenskt kök med inslag av det bästa från det italienska köketÄr du en passionerad och erfaren kock som älskar att skapa fantastiska matupplevelser? Vill du arbeta i en livlig och utvecklande miljö?
#
# kock, Cuisine Libanaise AB
# ['arbetsformedlingen.se']
# Vi söker dig som vill jobba heltid/deltid. Du som söker tjänsten bör ha tidigare erfarenhet från mellanösterns kök.
#
# kock, Linne Curry AB
# ['arbetsformedlingen.se']
# The Elephant är en Indisk Restaurang som serverar Indisk mat båda tandoori och curry rätter vi behöver en kock som kan förbereda och laga Indisk mat båda curry och tandoori rätter samt Indisk bröd och efterrätter
#
# Kock, Quinto Vilhelmina AB
# ['arbetsformedlingen.se']
# Afghan Kock sökes till Quinto i Vilhelmina!Är du en passionerad och driven kock med expertis inom afghansk matlagning? Brinner du för att skapa autentiska och smakrika rätter?
#
# Kock, Procivitas Privata Gymnasium AB
# ['arbetsformedlingen.se']
# ProCivitas söker kvalificerad kockProCivitas Privata Gymnasium Malmö är på god väg mot målet att vara Sveriges bästa gymnasieskola. Våra lokaler är moderna och centralt belägna och skolans mat och matsal är berömda i Malmö.
#
# Kock, Sandvikens Folkets Husfören Ekonomisk Förenin
# ['arbetsformedlingen.se']
# Restaurang Bolaget, som varje vardag har lunchservering, levererar all förtäring till Folkets hus konferensgäster och är välkända lokalt och i regionen för hög kvalitet i varor och tjänster och för sin höga servicenivå. Flera kvällar i månaden arrangeras också företagsevent, konserter eller annan underhållning i restaurangen.
#
# Kock, Uppsala kommun
# ['arbetsformedlingen.se']
# Eksätra HVBÄr du kreativ och nytänkande och brinner för att barn och ungdomar ska få uppleva kvalitativ matlagning och stötta dem till en fungerande kosthållning? Är du sugen på att jobba dagtid som kock?
#
# Kock, Restaurang Gilltuna AB
# ['arbetsformedlingen.se']
# Erfaren kock sökes till vårt arbetsteam på restaurang Bistrobox. vi vill gärna att du har minst 2 års erfarenhet av husmanskost, samt planering, inköp och du ska vara självgående.
#
# Kock, NEWREST INFLIGHT SWEDEN AB
# ['arbetsformedlingen.se']
# Vi söker en kreativ och passionerad kock! Brinner du för matlagning och vill vara en del av ett engagerat köksteam?
#
# Kock, Hotell Årjäng AB
# ['arbetsformedlingen.se']
# Vi önskar att stärka vårt team i köket med en kock till, till vår  restaurang på Hotell CharlottenbergVi ser att du:är genuint intresserad av matlagning, människor och serviceUnder arbetspasset ansvara du för att hålla köksområdet lokaler välkomnande. Vara behjälplig för våra gäster innan, under och efter besök och se till att de får bästa möjliga upplevelseHa en hög kompetensnivå och alltid hålla sig uppdaterad om arbetet i köket/restaurangen samt lösningsorienterad.
#
# Kock, Värdshuset Flottaren AB
# ['arbetsformedlingen.se']
# Flottaren söker nu ny kock då våran nuvarande tar pension efter 46år. Vi har öppet alla dagar förutom Midsommar, julafton och nyårsafton.
#
# Kock, Hotell Zinkensdamm AB
# ['arbetsformedlingen.se']
# Hotell Zinkensdamm ligger innanför tullarna, men samtidigt naturskönt med oslagbar miljö i närheten av Årstaviken. Vi bedriver hotell-, konferens- och vandrarhemsverksamhet.
#
# Kock, Stift Läckö Slott
# ['arbetsformedlingen.se']
# Kock, Restaurangverksamheten på Läckö SlottÄr du den nyckelpersonen vi söker till vårt restaurangteam?Ta chansen att jobba på Sveriges vackraste arbetsplats med måltiden, kulturarvet och den vackra naturen ständigt närvarande. Vår restaurang är belägen i Naturum Vänerskärgården - Victoriahuset som färdigställdes 2013.
#
# Kock, Borås kommun
# ['arbetsformedlingen.se']
# Är du en engagerad kock med passion för att skapa goda måltider som blir dagens höjdpunkt för våra boende och restauranggäster? Vill du arbeta i ett team där matlagning, omtanke och kvalitet står i fokus?
#
# Kock, ASOF SVERIGE AB
# ['arbetsformedlingen.se']
# Vi söker en erfaren kock till vårt kök – TillsvidareanställningHar du passion för matlagning och lång erfarenhet från köket? Då kanske du är den vi söker!Om tjänsten:Vi söker en kock med minst fem års dokumenterad erfarenhet av köksarbete och kockyrket.
#
# Kock, J2 Uthyrning AB
# ['arbetsformedlingen.se']
# J2 Uthyrning bemannar Stockholms bästa asiatiska restauranger. Du ska vara driven och ambitiös.
#
# Kock , Hindåsgården Konferens och Spa AB
# ['arbetsformedlingen.se']
# Hindåsgården är en av Västsveriges främsta konferensanläggningar, i ständig utveckling och förändring med sikte på att vara bäst i klassen. Du hittar oss mitt emellan Göteborg och Borås, 10 min från Landvetter flygplats, i en lugn och avkopplande miljö med skog och sjö som närmaste granne.
#
# Kock, Thai T4
# ['arbetsformedlingen.se']
# Hej! Restaurang Thai T4 i Halmstad söker 2 kockar inom det asiatiska köket ( laga asiatiska mat) Ett plus om du kan tala vietnamesiska.
#
# Kock, Systrarna Lun. AB
# ['arbetsformedlingen.se']
# Hej,Vi söker en Kock som är stresstålig och brinner att tillaga mat. Vi lägger stor vikt vid personlig lämplighet, det är viktigt att du passar in i arbetsgruppen.
#
# Kock, Restaurang Iribamba AB
# ['arbetsformedlingen.se']
# Restaurang ARTES, som ligger i Kulturhuset centralt i Stockholm, söker ny medarbetare i köket. Vi ser att Du har erfarenhet av att arbeta som kock, har lätt för att arbeta i team och beredd att jobba såväl dagtid som kvällstid och helger.
#
# Kock, Göteborgsfamiljen AB
# ['arbetsformedlingen.se']
# Taverna Averna är en stimmig New York-italian bistro beläget på Tredje Långgatan. Här erbjuder vi våra gäster allt ifrån högkvalitativ lunch, träffsäkra cocktail samt senkvällar med DJ och go stämning.
#
# Kock, Sandby Resort Holding AB
# ['arbetsformedlingen.se']
# Sonjas Camping ligger på norra Öland och är en stor och gemytlig familjecamping med många aktiviteter och fantastiska bad både i pool och på stranden. Hos oss trivs både kunder och personal!Vi söker nu kock till restaurangen för sommarsäsongen 2025  efter ett sent avhopp.
#
# Kock, Spahija, Sheremet
# ['arbetsformedlingen.se']
# Är du kock med erfarenhet från à la carte och lunch och har passion för matlagning med härliga råvaror? Då har vi jobbet för dig!
#
# Kock, Sävsjö kommun
# ['arbetsformedlingen.se']
# Sävsjö kommun är en liten kommun där det finns stora möjligheter att växa. I den lilla kommunen är det nära mellan människor – mellan dig och dina kollegor och mellan medarbetare och chefer.
#
# Kock, Sävsjö kommun, Serviceförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenSävsjö kommun är en liten kommun där det finns stora möjligheter att växa. I den lilla kommunen är det nära mellan människor – mellan dig och dina kollegor och mellan medarbetare och chefer.
#
# Kock, Memorio AB
# ['arbetsformedlingen.se']
# Memorio AB som driver konferens- och festanläggningarna van der Nootska Palatset, Cedergrenska Tornet och Stora Brännbo-konferens och hotell . Memorio ansvar också för catering till konferens och fest, t. ex.  till 7As anläggningar i Posthuset och Odenplan samt maten som serveras på Soppteatern på Stockholms Stadsteater och på Lilla Klara.
#
# Kock, Magnusson Restaurang AB
# ['arbetsformedlingen.se']
# Nu söker vi en kock för att förgylla vårat team. Vi ser att du kan jobba både i team och självständigt, ha eget ansvar och vara stresstålig.
#
# Kock, Utö Värdshus AB
# ['arbetsformedlingen.se']
# Vi söker dig som har relevant restaurangutbildning och minst två års dokumenterad erfarenhet från restaurangkök. Vi erbjuder ett brett utbud med allt från frukost, lunch och á la carte till bröllop och konferenser.
#
# Kock, Vedugn 550 grader AB
# ['arbetsformedlingen.se']
# Vi söker en passionerad kock till vårt team!Arbets plats Piazza RåsundaÄr du en kreativ och driven kock som älskar att arbeta med färska råvaror och skapa mat som gästerna minns? Då kan du vara den vi söker!Om oss:Vi är en familjär restaurang och pizzeria som ligger i hjärtat av Råsunda – bara ett stenkast från Strawberry Arena.
#
# Kock, SH Food AB
# ['arbetsformedlingen.se']
# Du ska tillaga olika sås, strimla och marinera olika köttprodukter, beställa och förpackning råvaror.
#
# Kock, Krogen i Bunge AB
# ['arbetsformedlingen.se']
# Är du redo att ta köket med storm och servera fantastisk mat? Då är du rätt kock för oss!
#
# kock, A Tavola AB
# ['arbetsformedlingen.se']
# Ostbutiken odengatan är en 100 år gammal delibutik specialiserad på hantillverkad mat. Vi servar vår kunder över disk i butik, med catering  och i vår Restaurang, en privatediningmatsal i toppklass.
#
# kock, Källarbyn AB
# ['arbetsformedlingen.se']
# Arbetet innebär: Förberedning, tillredning av menysortiment - mat, bakverk. Sedvanlig ordning och städning kök.
#
# Kock, Ronneby Hotell AB
# ['arbetsformedlingen.se']
# Drömjobbet för dig som brinner för matlagning och teamwork!Vill du arbeta som kock på en av sydöstra Sveriges mest välrenommerade resortanläggningar? Ronneby Brunn söker nu en passionerad och skicklig kock som vill bli en del av vårt framgångsrika team.
#
# Kock, OnurMiran AB
# ['arbetsformedlingen.se']
# Vi söker en grillkock till vår restaurang. Du ska vara självgående och kunna arbeta i ett team.
#
# Kock , Green Hotel AB
# ['arbetsformedlingen.se']
# Vi behöver stärka upp vårat team i köket inför sommarenGreen Hotel – högklassig konferensanläggning som serverar frukost, lunch och middag året runt. Svenskt kök med grunden i det medvetna klassiska köket med sikte på framtiden.
#
# Kock, Snabb Jobb Sverige AB
# ['arbetsformedlingen.se']
# Vi söker en passionerad och erfaren kock med specialisering inom grillning och oreintalisk mat för vårt restaurangteam i Helsingborg. Som kock kommer du att ansvara bland annat för att skapa läckra grillrätter för våra gäster.
#
# Kock, Jakhchali Restaurang AB
# ['arbetsformedlingen.se']
# Vi söker nu en kock på heltid till vårt härliga team! Vår meny varierar så vi uppskattar om du har erfarenhet av matlagning i restaurangmiljö, men det viktigaste är att du har viljan att lära dig och utvecklas.
#
# Kock, Hotellet vid Lilla Apelviken AB
# ['arbetsformedlingen.se']
# Laga mat på nya Restaurang Severins på Varbergs kusthotell. Nordiskt inspirerade rätter på råvaror i säsong och alltid nyfångat på menyn.
#
# Kock, Trivas På Råå AB
# ['arbetsformedlingen.se']
# Vi söker pigg och glad kock till vårt härliga team på Kajgatan 1 i Råå Hamn. Det är både dagtid, kväll och helg.
#
# Kock, Kama Sushi AB
# ['arbetsformedlingen.se']
# Vi söker en sushi kock eller vietnamesisk kock arbetsuppgifter är beredning och matlagning till matgäster som äta på plats och hemtagning.
#
# kock, Poonfood HB
# ['arbetsformedlingen.se']
# Vi på restaurang Slingerbulten söker nu en kock där vi serverar svensk husman. Minst 3 års erfarenhet är ett krav då vi söker en självgående kock.
#
# Kock, Segerblom Invest AB
# ['arbetsformedlingen.se']
# Gillar du högt tempo, älskar mat och service? KAJSAS söker nu engagerad kökspersonal till sommarsäsongen 2025 för KAJSAS I PARKEN!Vem är du?Vi söker dig som har tidigare erfarenhet av att jobba med mat - vare sig du arbetat i storkök, på en väletablerad krog eller i ett snabbmatskök med fastfood kan du vara rätt person för oss!
#
# Kock, Iss Facility Services AB
# ['arbetsformedlingen.se']
# Var 660:e person som går till arbetet i Sverige är en ISS-medarbetare och det är vi stolta över. Vi är ett av Sveriges och Nordens största tjänsteföretag samt har över 450 000 medarbetare världen över.
#
# Kock, Marho, Adwar
# ['arbetsformedlingen.se']
# Marcellos restaurang I Sölvesborgs kommun är en sommar restaurang som serverar både napolitansk pizza och alla carte och lunch Vi söker 1-2 kunniga  kockar som tycker att det roligt och laga mat .
#
# Kock, Missionsgården Strandhem
# ['arbetsformedlingen.se']
# Missionsgården Strandhem är en kristen kurs- och konferensgård. Vi söker dig som är duktig på att laga mat och som gärna jobbar tillsammans med andra.
#
# Kock, G Swensons Krog AB
# ['arbetsformedlingen.se']
# Som servitör/servitris på G Swensons arbetar Direkt mot våra gäster med ett en bra inställning till service. Med 200 platser inklusive uteservering serverar vi en ala carte meny för 2 sittningar per kväll, oftast två eller tre rätter.
#
# Kock, Östersundsbolaget AB
# ['arbetsformedlingen.se']
# Mitt i Östersund hittar du Norra Station. En restaurang, ett galleri och ett kafferosteri.
#
# KOCK, Spice N'rice Växjö AB
# ['arbetsformedlingen.se', 'arbetsformedlingen.se']
# Spice n Rice Växjö är nr 2 av 6 restauranger som vi har runt om i Sverige. Vi lagar Thai och kina mat på ala minute och servera när folk beställa.
#
# KOCK, Spice N'Rice Halmstad AB
# ['arbetsformedlingen.se', 'arbetsformedlingen.se']
# Spice n Rice HALMSTAD är nr 7 av 8 restauranger som vi har runt om i Sverige. Vi lagar Thai och kina mat på a la minuter och servera när folk beställa.
#
# Kock, Fisky Business AB
# ['arbetsformedlingen.se']
# Hej!Vi på Fisky Business, Dockan vill bredda truppen inför sommaren. A la carte meny med fokus på fisk.
#
# Kock, Ystads Matbod AB
# ['arbetsformedlingen.se']
# Kanske känner du till Tryffelsvinet i Kivik, det lilla huset mitt på torget som med djup inspiration från Italien och medelhavet kört på sedan mars 2021. Under sensommaren 2024 öppnade vi Kiviks ”lillasyster” Tryffelsvinet Ystad i det gamla stationshuset.
#
# Kock, Arjeplog Hotel Silverhatten AB
# ['arbetsformedlingen.se']
# Om jobbetSilver Resort - navet i turism- och biltestverksamheten i Arjeplog är en hotellkoncern med fokus på testindustri, konferenser, event och vinterturism. Vårt syfte är att ge våra gäster en helhetsupplevelse med bästa service, det bästa boendet och spännande event.
#
# Kock, Tierps kommun, Kostenheten
# ['offentligajobb.se']
# Om arbetsplatsenTierp är en kommun med en organisation i rätt storlek för dig som vill ha nära till chef, kollegor, politik och kunder. Här finns utrymme för både personlig utveckling och samverkan i organisationen.
#
# Kock , Tierps kommun
# ['arbetsformedlingen.se']
# Tierp är en kommun med en organisation i rätt storlek för dig som vill ha nära till chef, kollegor, politik och kunder. Här finns utrymme för både personlig utveckling och samverkan i organisationen.
#
# Kock, Värdshus i väst AB
# ['arbetsformedlingen.se']
# Arbetsbeskrivning Som kock i vår organisation jobbar du med dagens lunch, kvällsmenyer samt bistromeny. Du är en del i teamet med ledning av vår kökschef.
#
# Kock, Hotell Corallen AB
# ['arbetsformedlingen.se']
# Vi behöver förstärka vårt team i köket! Vi letar efter dig som brinner för att laga mat, kan ta egna initiativ, kan jobba självgående, har bra teamkänsla och är stresstålig.
#
# Kock, Terra&Zen AB
# ['arbetsformedlingen.se']
# Kock med erfarenhet sökes till vårt kökVi söker en engagerad och erfaren kock som trivs i högt tempo och har förmågan att hålla många bollar i luften. Du är självgående, stresstålig och en lagspelare som tar ansvar för både smak, tempo och kökets ordning.
#
# Kock, Ca Enterprise AB
# ['arbetsformedlingen.se']
# Johannebar strävar efter att vara den personliga kvarterskrogen som kombinerar familjär känsla och enkelhet. Vi söker dig som är självgående och van vid ett högt tempo.
#
# Kock, CA enterprise AB
# ['ledigajobb.se']
# Johannebar strävar efter att vara den personliga kvarterskrogen som kombinerar familjär känsla och enkelhet. Vi söker dig som är självgående och van vid ett högt tempo.
#
# KOCK, Hotell Mossbylund AB
# ['arbetsformedlingen.se']
# SKAPA MOSSBYMAGI MED OSSVill du vara en del av ett produktivt köksteam? Våra kök behöver nu förstärkning av erfarna och kreativa kockar.
#
# Kock, ARL in Tärendö AB
# ['arbetsformedlingen.se']
# Värme och gemenskap är viktigt för oss. Varje medlem i vårt team är lika viktig för att få våra gäster att uppleva vårt motto "Kom som gäst och åk som en vän".
#
# Kock , Nordgoo AB
# ['arbetsformedlingen.se']
# Om jobbetVi söker dig som vill jobba som kock hos oss, en av Stockholms finare kinesisk ramen restaurang! Vi söker dig som är positiv, självgående och stresstålig.
#
# Kock, Landskrona Kök & Catering AB
# ['arbetsformedlingen.se']
# Vi söker en skolkock till Landskrona kök Vill du ha ett av de viktigaste och roligaste uppdragen som finns? Hos oss får du som kock bidra till matglädje hela dagen för ett lustfyllt lärande!Du kommer jobba tillsammans med en köksassistent.
#
# Kock, Hotellgruppen i Säffle AB
# ['arbetsformedlingen.se']
# Home Hotel Bristol i Arvika söker nu efter en kock till vårt team!Vi letar efter en smaksäker, ordningsam och kreativ kock till vårt köksteam. Tjänsten är på 75% och du kommer jobba kvällar samt helger på ett rullande schema.
#
# Kock, Sundet 1 AB
# ['arbetsformedlingen.se']
# Vill du vara med och skapa smakupplevelser som gästerna minns? På Restauarang Sundet kombinerar vi kvalitet, kreativitet och kärlek till råvaran - och nu söker vi en kock.
#
# kock, dell Amore AB
# ['arbetsformedlingen.se']
# Vi söker efter en passionerad och erfaren kock med god kunskap inom det italienska köket. Du är noggrann, har ett öga för detaljer och trivs med att arbeta i team.
#
# Kock, Rasta Sverige AB
# ['arbetsformedlingen.se']
# Rasta Eksjö är en anläggning som ingår i den välkända Rasta kedjan med 30 mötesplatser runt om i Sverige där vi driver Restaurang, butik & hotellverksamhet. Här på Rasta Eksjö har vi en restaurang med fokus på svensk husmanskost, ett hotell samt en välsorterad trafik butik som drivs under varumärket PREEM.
#
# Kock, Nedergårdens Vilt & Natur FJ
# ['arbetsformedlingen.se']
# Nu söker vi personal till vår värmländska idylliska lilla viltrestaurang i Sysslebäck. Vi söker dig som älskar att laga mat vare sig du är kock eller inte.
#
# Kock, DNT AB
# ['arbetsformedlingen.se']
# Vi söker en Erfaren Kock till vår Thai Restaurang!Är du en passionerad kock med erfarenhet inom det asiatiska köket? Vill du vara med och skapa autentiska och smakrika thailändska rätter?
#
# Kock, Mat & Mingel 2 AB
# ['arbetsformedlingen.se']
# Ediths produktion är idag en komplett färdigmatsleverantör som levererar ca 1500 portioner mat, varje dag. All mat görs från grunden i köket i Alingsås och idag kan du äta Ediths goda mat i stora delar av Sverige.
#
# Kock, Fanguly
# ['arbetsformedlingen.se']
# Att jobba i Kina restaurang där laga du traditionell kinesiska mat. Ordna matmeny och beställa råd varor.
#
# Kock, Ragnerud Business AB
# ['arbetsformedlingen.se']
# Du besitter på några års erfarenhet eller utbildning från yrket, stor passion för matlagning och är smaksäker och noggrann i din matlagning. • Du som söker ska vara nytänkande och kreativ i ditt sätt att arbeta• Du som söker ska vara nytänkande och kreativ i ditt sätt att arbeta• Du är effektiv och ansvarsfull och vill vara med och utveckla restaurangen• Du uppskattar ordning och reda, både i ditt eget och dina kollegors arbete• Du är en riktig lagspelare men tar gärna egna initiativ när det behövsRagnerud Kök på Vandringsdestination i natursköna Dalslandvid Ragnerudsjön och i Kroppefjälls VildmarksområdeVi erbjuder logi, aktiviteter, restaurang, café och underbar vandring.
#
# Kock, Sportbaren På Stortorget AB
# ['arbetsformedlingen.se', 'arbetsformedlingen.se']
# Vi är en amerikansk sportbar med stort fokus på mat. Hos oss samverkar stämningen, inredningen, maten, servicen och sporten för varje gäst en premiumupplevelse.
#
# Kock, Sportbaren På Stortorget AB
# ['arbetsformedlingen.se', 'arbetsformedlingen.se']
# Nu har du chansen som går kockskolan eller likande att få ett superkul extra jobb på helgerna. Vi är en amerikansk sportbar med stort fokus på mat.
#
# Kock, Restaurang Twin City AB
# ['arbetsformedlingen.se']
# Om jobbetRestaurang Twin City, en välkänd mötesplats med passion för mat och service, söker nu en engagerad medarbetare till vårt serveringsteam. Vi erbjuder en dynamisk arbetsmiljö där kvalitet och gästnöjdhet står i centrum.
#
# Kock, Lin Zhu's Restaurang i Örebro AB
# ['arbetsformedlingen.se']
# Restaurang Lin Zhu´s är en Thai restaurang i Örebro vi inriktar oss på asiatiska maträtter. Vi har både meny a la carte, lunchbuffé och take - away.
#
# sushi kock , wok kock, Saigon Express i Örebro AB
# ['arbetsformedlingen.se']
# Restaurang Saigon har två enheter i Örebro . Du som sökande har tidigare jobbat inom asiatiskt kök och förstår dess ingredienser.
#
# Special kock  Sushi kock, Goyo sushi AB
# ['arbetsformedlingen.se']
# Goyo Sushi AB söker erfaren Sushi-kockGoyo Sushi AB söker en engagerad och erfaren sushi-kock till en av våra framgångsrika restauranger. Snart öppnar våran fjärde restaurangen.
#
# sushi kock,asiatisk mat kock, Restaurang Wang Bamboo AB
# ['arbetsformedlingen.se']
# bamboo restaurang är en Asiatisk restaurang i Simrishamn vi inriktar oss på asiatiska maträtter. Vi har både meny a la carte, lunchbuffé och take - away.
#
# 1.e kock, Kock. In AB
# ['arbetsformedlingen.se']
# Vi söker en 1. e kock till vårt team för olika kunduppdrag inom restaurang, storkök och mycket annat. Du ska vara stolt över ditt yrke och alltid arbeta professionellt, med fokus på kvalitet, struktur och yrkesetik.
#
# Kock Fjällbacka, Kristianstads kommun
# ['arbetsformedlingen.se']
# Kristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# Kock Fjällbacka, Kristianstad kommun, GS Måltid
# ['offentligajobb.se']
# Om arbetsplatsenKristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# Kock Helsingborg, Abilitet och Behov Utveckling i Sverige AB
# ['arbetsformedlingen.se']
# Vi söker dig duktiga kock som vill jobba för oss ute hos våra kunder runt om i Skåne Schemalagd var tredje helg. Mycket dagtid  men även en hel del kvällspass.
#
# Asiatisk Kock, Pongpower AB
# ['arbetsformedlingen.se']
# Pongpower är ett auktoriserat bemanningsföretag som endast bemannar våra egna restauranger. Vi driver asiatiska restauranger inom stor Stockholm.
#
# Sommarjobb Kock, TG Drift AB
# ['arbetsformedlingen.se']
# Vi söker nu en kock till sommaren, vi efterfrågar 1-3 års yrkesvana och som genomgått hygienprogram (HACCP). Tillagning av à la carte rätter samt till större festligheter så som bröllop och dylikt.
#
# Sushi Kock, Golden Goal Export & Import AB
# ['arbetsformedlingen.se']
# Asiatisk restaurang ligger i centrum Stockholm behöver en Sushikock. Vänligen respektera och sök enbart denna tjänst om du har tidigare erfarenhet som Sushikock.
#
# Thai kock, Luleå 2023 AB
# ['arbetsformedlingen.se']
# Corner är en trevlig pub och sportbar i centrala Luleå. Vår verksamhet växer och vi behöver nya talanger till vår nya restaurang!Vi söker en engagerad och erfaren thai-kock.
#
# Kock sökes, Nicklas Jonsson Livs AB
# ['arbetsformedlingen.se']
# ICA Supermarket Smedjebacken söker en självständig och matglad varmkökskock. Om rollenSom kock i vårt varmkök får du en varierad och kreativ vardag där du självständigt lagar färdiga rätter till försäljning i butik.
#
# Kock, vikariat, REGION ÖSTERGÖTLAND
# ['arbetsformedlingen.se']
# Region Östergötland driver tre skolor, vilka är samlade i en enhet under Regionutvecklingsnämnden. Vreta utbildningscentrum ligger strax utanför Linköping, Himmelstalunds utbildningscentrum är beläget i Norrköping, och Lunnevads folkhögskola ligger mellan Vikingstad och Mantorp.
#
# Vikarierande kock, Mullsjö kommun
# ['arbetsformedlingen.se']
# Mullsjö kommun är liten till ytan men rymmer stor livskvalitet. Här finns ett aktivt friluftsliv med fiskerika sjöar, natursköna vyer och miltals av vandrings- och cykelleder.
#
# Vikarierande kock, Mullsjö kommun
# ['offentligajobb.se']
# Om arbetsplatsenMullsjö kommun är liten till ytan men rymmer stor livskvalitet. Här finns ett aktivt friluftsliv med fiskerika sjöar, natursköna vyer och miltals av vandrings- och cykelleder.
#
# Kock, kväll , Uniparsco AB
# ['arbetsformedlingen.se']
# Är du en passionerad kock med erfarenhet och kärlek för matlagning? Medis Kök och Bar söker nu skickliga kockar för kvällspass som vill bli en del av vårt härliga team!Om oss:Medis Kök och Bar är en livlig och populär restaurang i hjärtat av Stockholm.
#
# Persisk/Afghansk Kock, Adrian R AB
# ['arbetsformedlingen.se']
# Restaurang Viking är väletablerad i Piteå. Den ligger nära kanalen och i närheten av Kommunhuset samt Strömbacka skolan.
#
# ---------------------------
#
# Kock, Järfälla kommun, Kvarnskolan
# ['offentligajobb.se']
# Om arbetsplatsenPå Utbildningsförvaltningen i Järfälla kommun arbetar omkring 3 100 medarbetare i någon av våra 39 förskolor, 22 skolor, gymnasium, vuxenutbildning och central förvaltning. Vår verksamhet präglas av våra ledord: professionalitet, kollegialitet och utvecklingskraft.
#
# Kock, Sävsjö kommun, Serviceförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenSävsjö kommun är en liten kommun där det finns stora möjligheter att växa. I den lilla kommunen är det nära mellan människor – mellan dig och dina kollegor och mellan medarbetare och chefer.
#
# Kock, Tierps kommun, Kostenheten
# ['offentligajobb.se']
# Om arbetsplatsenTierp är en kommun med en organisation i rätt storlek för dig som vill ha nära till chef, kollegor, politik och kunder. Här finns utrymme för både personlig utveckling och samverkan i organisationen.
#
# Kock, CA enterprise AB
# ['ledigajobb.se']
# Johannebar strävar efter att vara den personliga kvarterskrogen som kombinerar familjär känsla och enkelhet. Vi söker dig som är självgående och van vid ett högt tempo.
#
# Kock Fjällbacka, Kristianstad kommun, GS Måltid
# ['offentligajobb.se']
# Om arbetsplatsenKristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# Vikarierande kock, Mullsjö kommun
# ['offentligajobb.se']
# Om arbetsplatsenMullsjö kommun är liten till ytan men rymmer stor livskvalitet. Här finns ett aktivt friluftsliv med fiskerika sjöar, natursköna vyer och miltals av vandrings- och cykelleder.
#
# Kock förskola, Årjängs kommun
# ['offentligajobb.se']
# Om arbetsplatsenÅrjängs kommun är en stolt tillväxtkommun med framtidstro. Vi antar utmaningar med tillförsikt och mod tillsammans i samverkan.
#
# Vikarierande kock, Enköpings kommun Teknik- och serviceförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenEnköpings kommun är arbetsplatsen för dig som vill vara med och skapa det långsiktigt goda samhället. Här får du möjlighet till personlig utveckling samtidigt som du får chansen att göra verklig skillnad för alla som lever och verkar i Enköping.
#
# Kock till Tollaregården, Kristianstad kommun, GS Måltid
# ['offentligajobb.se']
# Om arbetsplatsenKristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# Kock till Norregårdskolan, Växjö kommun, Måltidsorganisationen
# ['offentligajobb.se']
# Om arbetsplatsenNu söker vi dig, som tillsammans med oss vill göra nytta för dem vi är till för! Växjö kommun är Kronobergs största arbetsgivare som varje dag, året runt, arbetar för våra invånare, företag och besökare.
#
# Kock till Eriksdalskolan, Skövde kommun, Avdelning måltidsverksamhet
# ['offentligajobb.se']
# Om arbetsplatsenI sektor service spelar du en viktig roll i att hålla vårt samhälle igång. Vi arbetar med allt från fastighetsskötsel, offentliga måltider och lokalvård till underhåll av gator, parker och ledningsnät – här bidrar du direkt till att skapa en bättre vardag för våra invånare.
#
# Kock till Alviksskolan, Luleå kommun, Arbetsmarknads- och utbildningsförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenHej!Vi är glada över ditt intresse för att bli en del av Luleå kommun. Hos oss får du möjlighet att arbeta i en stimulerande och utvecklande miljö, där vi strävar efter att ge dig en bra medarbetarupplevelse.
#
# Kock till Henriksdalskolan, Vellinge kommun
# ['offentligajobb.se']
# Om arbetsplatsenDu vet säkert att Vellinge i flera år utsetts till Sveriges bästa skolkommun. Hos oss kommer du att mötas av höga ambitioner, förväntningar och goda arbetsförutsättningar.
#
# Kock till Duved, Åre Kommun
# ['offentligajobb.se']
# Om arbetsplatsenVi på Åre kommun skapar förutsättningar för att alla som bor eller vistas här kan förverkliga sina drömmar. I vår storslagna fjällmiljö samsas förväntansfulla skidåkare med jordnära livskonstnärer.
#
# Kock inom Måltidsservice, Sölvesborgs kommun, Samhällsbyggnad Fritid och Kulturförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenStolthet, trivsel, lojalitet, bra chefer och kollegor och en känsla av att bidra till ett bättre samhälle. Så känner medarbetarna för Sölvesborgs kommun som arbetsgivare.
#
# Kock till Bullerbyns förskolekök, Kiruna kommun, Måltidsverksamhet
# ['offentligajobb.se']
# Om arbetsplatsenEn sak är säker. Med oss gör du skillnad.
#
# Kock, Bemanningsenheten gemensam service, Kristianstad kommun, Gemensam service
# ['offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenKristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# 1:e Kock inom Måltidsservice, Sölvesborgs kommun, Samhällsbyggnad Fritid och Kulturförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenStolthet, trivsel, lojalitet, bra chefer och kollegor och en känsla av att bidra till ett bättre samhälle. Så känner medarbetarna för Sölvesborgs kommun som arbetsgivare.
#
# Kock Till Pinchos Halmstad, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Till Pinchos Halmstad? Läs vidare!
#
# Kock till poolen 80%, Ronneby kommun, Kostenhet
# ['offentligajobb.se']
# Om arbetsplatsenNu har du chansen att bli en av oss!Vi arbetar tillsammans med hjärta och kvalitet för att kunna ge bästa möjliga service till Ronneby kommuns invånare. Ronneby ligger vackert mellan hav och skog i mitten av Blekinge.
#
# Kock Hos O’Learys Märsta, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Märsta? Läs vidare!
#
# Kock Hos O’Learys Ystad, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Ystad? Läs vidare!
#
# Kock Till Pinchos Ljungby, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Till Pinchos Ljungby? Läs vidare!
#
# Kock Till Pinchos Vetlanda, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Till Pinchos Vetlanda? Läs vidare!
#
# OLearys Linköping Söker Kock, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som OLearys Linköping Söker Kock? Läs vidare!
#
# Kock, Bemanningsenheten gemensam service, Kristianstad kommun, Gemensam service
# ['offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenKristianstads kommun har drygt 7 000 medarbetare som gör skillnad i människors vardag, varje dag. Hos oss hittar du medarbetare som brinner för välfärden och vill utveckla idéer till verklighet.
#
# Kock sökes till Gillestugan Jerntorget, Irish Embassy
# ['ledigajobb.se']
# Nyöppnade Gillestugan Jerntorget söker kock! Kan du ett och annat inom matlagning?
#
# Kock Hos O’Learys i Borlänge, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys? Läs vidare!
#
# Kock Hos O’Learys i Gävle, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys? Läs vidare!
#
# Kock Hos O’Learys i Hemavan, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys? Läs vidare!
#
# Kock Till O`Learys Kungälv Sökes!, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Till O`Learys Kungälv Sökes!? Läs vidare!
#
# Kock Hos O’Learys Sommarjobb/Extrajobb i Norrköping, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Sommarjobb/Extrajobb? Läs vidare!
#
# Kock Extra Vid Behov i Växjö, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Extra Vid Behov? Läs vidare!
#
# Bli Kock Hos O’Learys i Vänersborg, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Bli Kock Hos O’Learys? Läs vidare!
#
# Kock Hos O’Learys Järntorget i Göteborg, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Järntorget? Läs vidare!
#
# Vi Söker En Kock Till Pinchos Falun, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Vi Söker En Kock Till Pinchos Falun? Läs vidare!
#
# Kock Hos O’Learys Extra Kvällar/helger i Umeå, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Extra Kvällar/helger? Läs vidare!
#
# Kock till The Fishery Färjkajen i Västerås, Restaurang brygga och bord AB
# ['ledigajobb.se']
# Arbetsbeskrivning   Kock till The Fishery Färjkajen i Västerås  Ett Fiskeri, Fishery, är någon som odlar och skapar produkter från havet och andra vatten. Ett Fiskeri har hand om all typ av fisk, skaldjur och ätbara vattenväxter.
#
# Kock Hos O’Learys Ystad Extra Vid Behov, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Hos O’Learys Ystad Extra Vid Behov? Läs vidare!
#
# Intresseanmälan timvikarie Kock och Ekonomibiträde till Bemanningsenheten, Falkenbergs kommun, Bemanningsenheten
# ['offentligajobb.se']
# Om arbetsplatsenHär i Falkenbergs kommun kan du göra stor skillnad. Vårt jobb är att erbjuda god kommunal service i livets alla skeden.
#
# Kock till Tubberödshus, Lilldal, Kvarnbackens äldreboende, semestervikariat, Tjörns kommun, Vård- och omsorgsavdelningen
# ['offentligajobb.se']
# Om arbetsplatsenPå Tjörn får medarbetarna ta plats! Inom Tjörns kommunkoncern står arbetsklimat och omsorg om varandra högt i kurs.
#
# Kock sökes till Irish Embassy Pub & Grill, Irish Embassy
# ['ledigajobb.se']
# Kan du ett och annat inom matlagning? Då är du perfekt för oss!
#
# Kock Till Köket På Pinchos Sälen Jobba En Sommar I Fjällen, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Kock Till Köket På Pinchos Sälen Jobba En Sommar I Fjällen? Läs vidare!
#
# Är du kock och brinner för matlagning? Välkommen till Solrosen äldreboende!, Ulricehamns kommun, Kost
# ['offentligajobb.se']
# Om arbetsplatsenUlricehamns kommun är inne i en fortsatt tillväxtfas. På bara några år har vi gått från liten till större, utan att tappa vår identitet.
#
# Passionerad à la carte-kock sökes till exklusiva Eriksberg Vilt & Natur, StudentConsulting
# ['monster.se']
# Eriksberg Hotel & Naturs verksamhet i Karlshamn fortsätter att växa och nu hjälper vi dem utöka deras duktiga team med fler erfarna kockar, som tillsammans med vår gastronomiska ledare Peter J Skogström och Linus Hornwall ska utveckla verksamheten!Information om uppdraget:. .
#
# Sous Chef Hos O’Learys Linköping, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Sous Chef Hos O’Learys Linköping? Läs vidare!
#
# Kockar till Björndammens skola, Partille kommun, Utbildningsförvaltningen
# ['offentligajobb.se']
# Om arbetsplatsenPartille kommun har idag 40 000 invånare och är en förstad i utveckling. Det är upp till oss 2 900 anställda att leverera kvalitet och service som gör det gott att växa upp, arbeta och leva i Partille.
#
# Arbetsledare till enheten för arbetsträning och arbetsmarknadsanställningar, Malmö stad
# ['offentligajobb.se']
# Om arbetsplatsenRef: 20251515ArbetsuppgifterArbetsuppgifterVi söker en arbetsledare/kock till Malmö Stad och Arbetsmarknadsavdelningens egna arbetslag, med placering Café Agnes Järnyxegatan 11. Du kommer att arbeta med arbetsmarknadsanställda inom kök och målgruppen omfattar Malmöbor som får försörjningsstöd samt ungdomar mellan 18 och 29 år från Individ- och familjeomsorgen.
#
# Köksansvarig till Parkrestaurangen, Mullsjö kommun
# ['offentligajobb.se']
# Om arbetsplatsenMullsjö kommun är liten till ytan men rymmer stor livskvalitet. Här finns ett aktivt friluftsliv med fiskerika sjöar, natursköna vyer och miltals av vandrings- och cykelleder.
#
# Timvikarierande kockar till Sundsvalls kommun, Servicecenter
# ['offentligajobb.se']
# Om arbetsplatsenVi söker nu flera kockar för att utöka vårt arbetslag med timvikarier. Är du den vi söker?Sundsvalls Mat & Måltider står för den offentliga gastronomin i Sundsvalls Kommun.
#
# Timvikarier inom Måltider, Samhällsbyggnadsförvaltningen, Hörby kommun
# ['offentligajobb.se']
# Om arbetsplatsenAtt arbeta i Hörby kommunHörby kommun med 15 700 invånare ligger mitt i Skånes hjärta med det mesta och det bästa runt hörnet. Hörby är en mycket gammal handelsort.
#
# KOCKAR i Värnamo, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som KOCKAR? Läs vidare!
#
# Cheerleader Wanted! i Kirkenes, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Cheerleader Wanted!? Läs vidare!
#
# Cheerleader Wanted! i Kirkenes, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Cheerleader Wanted!? Läs vidare!
#
# Kock/köksbiträde i Mölnlycke,
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Kock/köksbiträde? Läs vidare!
#
# Kock/köksbiträde i Mölnlycke,
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Kock/köksbiträde? Läs vidare!
#
# O'Learys Is Looking For New Champions/FOODMEISTERS! i Kirkenes, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Is Looking For New Champions/FOODMEISTERS!? Läs vidare!
#
# O'Learys Is Looking For New Champions/FOODMEISTERS! i Kirkenes, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Is Looking For New Champions/FOODMEISTERS!? Läs vidare!
#
# O'Learys Is Looking For New Chef And Kitchen Help! i Oslo, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Is Looking For New Chef And Kitchen Help!? Läs vidare!
#
# O'Learys Is Looking For New Chef And Kitchen Help! i Oslo, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Is Looking For New Chef And Kitchen Help!? Läs vidare!
#
# O'Learys Letar Efter Nya Mästare/ FOODMEISTERS i Mölnlycke, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Letar Efter Nya Mästare/ FOODMEISTERS? Läs vidare!
#
# O'Learys Letar Efter Nya Mästare/ FOODMEISTERS i Nässjö, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Letar Efter Nya Mästare/ FOODMEISTERS? Läs vidare!
#
# O'Learys Letar Efter Nya Mästare/ FOODMEISTERS i Nässjö, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O'Learys Letar Efter Nya Mästare/ FOODMEISTERS? Läs vidare!
#
# OLearys Gävle Och Sandviken Söker Kökschef, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som OLearys Gävle Och Sandviken Söker Kökschef? Läs vidare!
#
# OLearys Hemsedal Søker Kokker Til Vinter Sesong!, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som OLearys Hemsedal Søker Kokker Til Vinter Sesong!? Läs vidare!
#
# OLearys Hemsedal Søker Kokker Til Vinter Sesong!, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som OLearys Hemsedal Søker Kokker Til Vinter Sesong!? Läs vidare!
#
# O`Learys Drammen Søker Kokk, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O`Learys Drammen Søker Kokk? Läs vidare!
#
# O`Learys Drammen Søker Kokk, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som O`Learys Drammen Søker Kokk? Läs vidare!
#
# Olearys Bardufoss / Bardufoss Hotel Is Looking For People To Work Night Shift, Olearys
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Olearys Bardufoss / Bardufoss Hotel Is Looking For People To Work Night Shift? Läs vidare!
#
# Sous Chef Hos O’Learys Linköping, Olearys
# ['studentjob.se', 'studentjob.se']
# Letar du efter ett utmanande jobb som Sous Chef Hos O’Learys Linköping? Läs vidare!
#
# Vi Vill Bli Fler I Köket På Pinchos Varberg, Pinchos
# ['studentjob.se']
# Letar du efter ett utmanande jobb som Vi Vill Bli Fler I Köket På Pinchos Varberg? Läs vidare!
#
# Timavlönade vikarier, bemanningsavdelningen, Varbergs kommun, Bemanningsavdelningen
# ['offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenI Varbergs kommun är vi cirka 5 000 medarbetare som delar en och samma verksamhetsidé: Vi ska förenkla människors vardag och inspirera dem att uppnå sina drömmar. Detta gör vi på väldigt många olika sätt, det finns mer än 135 olika yrken i vår breda verksamhet.
#
# Timavlönade vikarier, bemanningsavdelningen, Varbergs kommun, Bemanningsavdelningen
# ['offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenI Varbergs kommun är vi cirka 5 000 medarbetare som delar en och samma verksamhetsidé: Vi ska förenkla människors vardag och inspirera dem att uppnå sina drömmar. Detta gör vi på väldigt många olika sätt, det finns mer än 135 olika yrken i vår breda verksamhet.
#
# Timavlönade vikarier, bemanningsavdelningen, Varbergs kommun, Bemanningsavdelningen
# ['offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenI Varbergs kommun är vi cirka 5 000 medarbetare som delar en och samma verksamhetsidé: Vi ska förenkla människors vardag och inspirera dem att uppnå sina drömmar. Detta gör vi på väldigt många olika sätt, det finns mer än 135 olika yrken i vår breda verksamhet.
#
# Timavlönade vikarier, bemanningsavdelningen, Varbergs kommun, Bemanningsavdelningen
# ['offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenI Varbergs kommun är vi cirka 5 000 medarbetare som delar en och samma verksamhetsidé: Vi ska förenkla människors vardag och inspirera dem att uppnå sina drömmar. Detta gör vi på väldigt många olika sätt, det finns mer än 135 olika yrken i vår breda verksamhet.
#
# Timavlönade vikarier, bemanningsavdelningen, Varbergs kommun, Bemanningsavdelningen
# ['offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se', 'offentligajobb.se']
# Om arbetsplatsenI Varbergs kommun är vi cirka 5 000 medarbetare som delar en och samma verksamhetsidé: Vi ska förenkla människors vardag och inspirera dem att uppnå sina drömmar. Detta gör vi på väldigt många olika sätt, det finns mer än 135 olika yrken i vår breda verksamhet.
#
# Köksansvarig kock till Jakobsgårdsskolans kök, Borlänge kommun, Verksamhetsstöd/Kost- och lokalservice
# ['offentligajobb.se']
# Om arbetsplatsenVill du vara med och skapa matglädje med vällagade måltider och utveckla ett Borlänge som tar ansvar för miljön både nu och i framtiden?Kost- och lokalservice erbjuder måltid och städtjänster till förskola, grundskola, gymnasium samt särskilt boende. Kostservice består idag av cirka 70 enheter uppdelade på centralkök, kök med egentillagning och mottagningskök.
#
# Köksansvarig kock till Sundsvalls mat och måltider, Anemonens kök, Servicecenter
# ['offentligajobb.se']
# Om arbetsplatsenSundsvalls kommun har ungefär 8000 medarbetare och är betydelsefull för vårt samhälle. Vi är Sundsvalls största arbetsgivare med flera arbetsplatser inom olika verksamheter och runt 300 olika yrken.
#
# Number of hits, excluding arbetsformedlingen.se = 78
#
# Total number of hits = 775
